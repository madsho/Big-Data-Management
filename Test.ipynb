# %%
import pandas as pd

# %%
df = pd.read_csv('SBAnational.csv')
df.head(5)
# Out:
#                                        LoanNr_ChkDgt  Name  City  State  Zip  \
# 0  1000014003,ABC HOBBYCRAFT,EVANSVILLE,IN,47711,...   NaN   NaN    NaN  NaN
# 1  1000024006,LANDMARK BAR & GRILLE (THE),NEW PAR...   NaN   NaN    NaN  NaN
# 2  1000034009,"WHITLOCK DDS, TODD M.",BLOOMINGTON...   NaN   NaN    NaN  NaN
# 3  1000044001,"BIG BUCKS PAWN & JEWELRY, LLC",BRO...   NaN   NaN    NaN  NaN
# 4  1000054004,"ANASTASIA CONFECTIONS, INC.",ORLAN...   NaN   NaN    NaN  NaN
#
#    Bank  BankState  NAICS  ApprovalDate  ApprovalFY  ...  RevLineCr  LowDoc  \
# 0   NaN        NaN    NaN           NaN         NaN  ...        NaN     NaN
# 1   NaN        NaN    NaN           NaN         NaN  ...        NaN     NaN
# 2   NaN        NaN    NaN           NaN         NaN  ...        NaN     NaN
# 3   NaN        NaN    NaN           NaN         NaN  ...        NaN     NaN
# 4   NaN        NaN    NaN           NaN         NaN  ...        NaN     NaN
#
# ...
